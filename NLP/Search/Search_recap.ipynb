# %%
from sklearn.metrics.pairwise import cosine_similarity
import numpy as np

# %%
import pandas as pd
filepath = "https://raw.githubusercontent.com/hamzafarooq/maven-mlsystem-design-cohort-1/main/data/miami_hotels.csv"

data = pd.read_csv(filepath)

# %%
documents = data.review.values

# %%
def get_results(query, query_vector, word_vectors):
    cosine_sim = cosine_similarity(query_vector, word_vectors)
    print(f"Results for query '{query}'")
    result = pd.DataFrame(data = {"documents": documents, 'similarity': cosine_sim[0]}).sort_values("similarity", ascending=False)
    return result

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
tfidf_vectorizer = TfidfVectorizer(stop_words='english')
tfidf_matrix = tfidf_vectorizer.fit_transform(documents)

def sklearn_search(query):
  query_vector = tfidf_vectorizer.transform([query])
  return get_results(query, query_vector, tfidf_matrix)

# %%
query = 'near the beach'

# %%
tfidf_result = sklearn_search(query).reset_index(drop=True)
tfidf_result
# Out:
# Results for query 'near the beach'
#                                               documents  similarity
# 0     This is my second time coming to this hotel, a...    0.435463
# 1     The location is unbeatable, so near to the bea...    0.378574
# 2     The staff team is amazing! We loved our room a...    0.378527
# 3     Great location, room was as expected. Big and ...    0.367309
# 4     Really reccomend it. Very nice and clean hotel...    0.354757
# ...                                                 ...         ...
# 2506  Lautaro was great …he took care of our order a...    0.000000
# 2507  Perfect getaway with pleasant staff members!  ...    0.000000
# 2508  James at the pool was the bomb! Service was im...    0.000000
# 2509  The service was amazing ! Ricardo kept checkin...    0.000000
# 2510  This was our first visit to Miami with our son...    0.000000
#
# [2511 rows x 2 columns]

# %%
# !pip install rank_bm25
# Out:
# Collecting rank_bm25
#   Downloading rank_bm25-0.2.2-py3-none-any.whl (8.6 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from rank_bm25) (1.23.5)
# Installing collected packages: rank_bm25
# Successfully installed rank_bm25-0.2.2

# %%
from rank_bm25 import BM25Okapi

corpus = documents

tokenized_corpus = [doc.lower().split(" ") for doc in corpus]

bm25 = BM25Okapi(tokenized_corpus)

# %%
k = 10
tokenized_query = query.lower().split(' ')
bm25_results = bm25.get_top_n(tokenized_query, corpus, n=k)

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
tfidf_simple= TfidfVectorizer(lowercase =False)
tfidf_simple_matrix = tfidf_simple.fit_transform(documents)
query_vector = tfidf_simple.transform([query])

tfidf_simple_result = get_results(query, query_vector, tfidf_simple_matrix).reset_index(drop = True)
# Out:
# Results for query 'near the beach'

# %%
pd.DataFrame(data = {"TF-IDF-S":tfidf_simple_result[:k].documents,"TF-IDF":tfidf_result[:k].documents, "BM25":bm25_results})
# Out:
#                                             TF-IDF-S  \
# 0  This is my second time coming to this hotel, a...
# 1  The staff team is amazing! We loved our room a...
# 2  Really reccomend it. Very nice and clean hotel...
# 3  The Urbanica Fifth it's amazing place, the loc...
# 4  Everything is great but could have a little la...
# 5  The location is unbeatable, so near to the bea...
# 6  My friends and I came for spring break and thi...
# 7  The staff was super friendly and accommodating...
# 8  This hotel is in an excellent location near ma...
# 9  VERY accommodating.  We had an early flight in...
#
#                                               TF-IDF  \
# 0  This is my second time coming to this hotel, a...
# 1  The location is unbeatable, so near to the bea...
# 2  The staff team is amazing! We loved our room a...
# 3  Great location, room was as expected. Big and ...
# 4  Really reccomend it. Very nice and clean hotel...
# 5  Quaint, lovely hotel in the center of everythi...
# 6  The Urbanica Fifth it's amazing place, the loc...
# 7  The staff was super friendly and accommodating...
# 8  Everything is great but could have a little la...
# 9  My friends and I came for spring break and thi...
#
#                                                 BM25
# 0  The staff team is amazing! We loved our room a...
# 1  The Urbanica Fifth it's amazing place, the loc...
# 2  Really reccomend it. Very nice and clean hotel...
# 3  The staff was super friendly and accommodating...
# 4  Great location, room was as expected. Big and ...
# 5  Thanks to Paola and Marcel first of all.\nSimp...
# 6  Everything is great but could have a little la...
# 7  This is my second time coming to this hotel, a...
# 8  Best location in Maimi ocean drive. The rooms ...
# 9  It was an amazing check-in and information on ...

# %%
import re

def process_text(text):
  text = text.lower()
  text = re.sub(r'[^a-z ]', ' ', text)
  return text

def vocab_parser(corpus):
  joined_corpus = process_text(' '.join(corpus))
  joined_corpus = re.sub(r'[^a-z ]', ' ', joined_corpus)
  vocab = list(set(joined_corpus.split(' ')))
  return {vocab[i]: i for i in range(len(vocab))}

# %%
vocab = vocab_parser(documents)

def compute_bow(text, vocab):
  vector = np.zeros((len(vocab)))

  text = process_text(text)
  tokens = text.split(' ')

  for token in tokens:
    vector[vocab[token]] +=1

  return vector

# %%
vectors = np.array([compute_bow(document, vocab) for document in documents])

# %%
def bow_search(query):
  query = process_text(query)
  query_vector = compute_bow(query, vocab).reshape(1,-1)
  return get_results(query, query_vector, vectors).reset_index(drop = True)

# %%
bow_results = bow_search(query)
# Out:
# Results for query 'near the beach'

# %%
pd.DataFrame(data = {"TF-IDF-S":tfidf_simple_result[:k].documents,"TF-IDF":tfidf_result[:k].documents, "BM25":bm25_results, "Bow": bow_results[:k].documents})
# Out:
#                                             TF-IDF-S  \
# 0  This is my second time coming to this hotel, a...
# 1  The staff team is amazing! We loved our room a...
# 2  Really reccomend it. Very nice and clean hotel...
# 3  The Urbanica Fifth it's amazing place, the loc...
# 4  Everything is great but could have a little la...
# 5  The location is unbeatable, so near to the bea...
# 6  My friends and I came for spring break and thi...
# 7  The staff was super friendly and accommodating...
# 8  This hotel is in an excellent location near ma...
# 9  VERY accommodating.  We had an early flight in...
#
#                                               TF-IDF  \
# 0  This is my second time coming to this hotel, a...
# 1  The location is unbeatable, so near to the bea...
# 2  The staff team is amazing! We loved our room a...
# 3  Great location, room was as expected. Big and ...
# 4  Really reccomend it. Very nice and clean hotel...
# 5  Quaint, lovely hotel in the center of everythi...
# 6  The Urbanica Fifth it's amazing place, the loc...
# 7  The staff was super friendly and accommodating...
# 8  Everything is great but could have a little la...
# 9  My friends and I came for spring break and thi...
#
#                                                 BM25  \
# 0  The staff team is amazing! We loved our room a...
# 1  The Urbanica Fifth it's amazing place, the loc...
# 2  Really reccomend it. Very nice and clean hotel...
# 3  The staff was super friendly and accommodating...
# 4  Great location, room was as expected. Big and ...
# 5  Thanks to Paola and Marcel first of all.\nSimp...
# 6  Everything is great but could have a little la...
# 7  This is my second time coming to this hotel, a...
# 8  Best location in Maimi ocean drive. The rooms ...
# 9  It was an amazing check-in and information on ...
#
#                                                  Bow
# 0  Everything is great but could have a little la...
# 1  Spacious rooms but located in North Beach away...
# 2  This is the perfect hotel for families or grou...
# 3  Xavier at the beach was the best! It was a gre...
# 4  We really enjoyed our stay at Axel Beach the s...
# 5  Overall very nice time and enjoyed the hotel a...
# 6  The Hotel is very near the Beach area with all...
# 7  Great stay at the Gates hotel. Great amenities...
# 8  Justin had an amazing energy! We loved our roo...
# 9  Such a treat to do a Daycation at the Carillon...
